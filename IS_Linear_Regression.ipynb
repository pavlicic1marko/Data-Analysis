# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(0)
n=20
x=np.linspace(0, 10, n)
y=2*x + 1 + 3*np.random.rand(n)
# change x to two dimensional array
x_refactored= x[:,np.newaxis]

# %%
model = LinearRegression(fit_intercept=True)
model.fit(x_refactored,y)
# Out:
# LinearRegression()

# %%
plt.plot(x_refactored,y,'o')
#od 0 do 10 na x osi, 100 tacaka
xfit =np.linspace(0,10,100)
yfit =model.predict(xfit[:,np.newaxis])
plt.plot(xfit, yfit, color='black')
plt.plot(np.vstack([x,x]), np.vstack([y,model.predict(x[:,np.newaxis])]),color='green')

# %%
print(model.coef_, model.intercept_)
# Out:
# [1.98211282] 2.8341003576874932
